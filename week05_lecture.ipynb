# %% [markdown]
# # Week 5 - Plotting with `matplotlib`
#
# Charlotte Desvages

# %% [markdown]
# ## A simple plot

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [1, 3, 4, 2]

plt.plot(x, y)
plt.show()

# %%
import numpy as np

x = np.linspace(-2*np.pi, 2*np.pi, 100)
y = np.cos(x)

fig, ax = plt.subplots()
ax.plot(x, y, 'r+')
plt.show()

# %% [markdown]
# ## Figures and Axes
#
# Instead of using `plt.plot()`, we can have more control over *where* we plot something by first creating a `Figure` and one or more `Axes`.

# %%
fig, ax = plt.subplots(1, 3)
ax[2].plot(x, y)
plt.show()

# %% [markdown]
# ## Customising plots
#
# Consult [the documentation](https://matplotlib.org/stable/users/index.html)! Useful resources are the Examples Gallery and the Tutorials.

# %%
import numpy as np
np.random.seed(19680801)
import matplotlib.pyplot as plt


fig, ax = plt.subplots()
for color in ['tab:blue', 'tab:orange', 'tab:green']:
    n = 750
    x, y = np.random.rand(2, n)
    scale = 200.0 * np.random.rand(n)
    ax.scatter(x, y, c=color, s=scale, label=color,
               alpha=0.3, edgecolors='none')

ax.legend()
ax.grid(False)

plt.show()
